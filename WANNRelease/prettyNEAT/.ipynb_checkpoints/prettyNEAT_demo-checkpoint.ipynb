# %%
# To train call 'neat_train.py' with arguments.
# !python neat_train.py -h

# %%
# Train using default NEAT parameters on cart-pole swing-up with a small population and few generations
# !cat p/quickTest.json
# !python neat_train.py -p p/quickTest.json

# %%
# -- View stats of a completed run
# Rows:
# 0 - Fitness evaluations used
# 1 - Median fitness of population
# 2 - Max fitness of population
# 3 - Top fitness every achieved
# 4 - Median number of nodes of individuals in population
# 5 - Median number of connections of individuals in population
from matplotlib import pyplot as plt
import numpy as np
stats = np.loadtxt('log/sept22__stats.out', delimiter=',')
fig, ax = plt.subplots()
x = stats[:,0]
y = stats[:,[1,2,3]]
plt.plot(y)
plt.legend(['Median Fitness','Max Fitness','Best Fitness'])
plt.xlabel('Evaluations')
plt.ylabel('Fitness')
# Out:
# Text(0, 0.5, 'Fitness')

# %%
# -- View Topology of Network
# Lighter color connections are connected to earlier layers (NOT weight strength)
import vis as nv
nv.viewInd('demo/swingup/test_best.out','swingup')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-30727314c5e4> in <module>
#       1 # -- View Topology of Network
#       2 # Lighter color connections are connected to earlier layers (NOT weight strength)
# ----> 3 import vis as nv
#       4 nv.viewInd('demo/swingup/test_best.out','swingup')
#
# ~/Desktop/THESIS/brain-tokyo-workshop/WANNRelease/prettyNEAT/vis/__init__.py in <module>
# ----> 1 from .lplot import *
#       2 from .neatVis import *
#       3 from .viewInd import *
#
# ~/Desktop/THESIS/brain-tokyo-workshop/WANNRelease/prettyNEAT/vis/lplot.py in <module>
#       4 from matplotlib import pyplot as plt
#       5 import numpy as np
# ----> 6 import seaborn as sns
#       7
#       8
#
# ~/opt/anaconda3/envs/WANN/lib/python3.7/site-packages/seaborn/__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# ~/opt/anaconda3/envs/WANN/lib/python3.7/site-packages/seaborn/rcmod.py in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#       8
#       9
#
# ~/opt/anaconda3/envs/WANN/lib/python3.7/site-packages/seaborn/palettes.py in <module>
#       7 from .external import husl
#       8
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11
#
# ~/opt/anaconda3/envs/WANN/lib/python3.7/site-packages/seaborn/utils.py in <module>
#       9 import numpy as np
#      10 from scipy import stats
# ---> 11 import pandas as pd
#      12 import matplotlib as mpl
#      13 import matplotlib.colors as mplcol
#
# ~/opt/anaconda3/envs/WANN/lib/python3.7/site-packages/pandas/__init__.py in <module>
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat.numpy import (
#      23     _np_version_under1p16,
#      24     _np_version_under1p17,
#
# ~/opt/anaconda3/envs/WANN/lib/python3.7/site-packages/pandas/compat/numpy/__init__.py in <module>
#      19 if _nlv < "1.15.4":
#      20     raise ImportError(
# ---> 21         "this version of pandas is incompatible with numpy < 1.15.4\n"
#      22         f"your numpy version is {_np_version}.\n"
#      23         "Please upgrade numpy to >= 1.15.4 to use this pandas version"
#
# ImportError: this version of pandas is incompatible with numpy < 1.15.4
# your numpy version is 1.15.2.
# Please upgrade numpy to >= 1.15.4 to use this pandas version

# %%
# -- View Behavior of Network
# !python neat_test.py -p p/swingup.json -i demo/swingup/test_best.out --view True

# %%
# -- Compare Replicates
# Run several experiments 
#  for i in {0..10}; do python neat_train.py -p p/swingup.json -n 96 -o tanh_$i; done
#  for i in {0..10}; do python neat_train.py -p p/swing_allAct.json -n 96 -o allAct_$i; done
#
# View results as median and quartiles
#
import vis as nv
experiment_1 = 'demo/swingup/tanh'
experiment_2 = 'demo/swingup/allAct'
_,_,bestRun = nv.viewReps([experiment_1,experiment_2],label=['Tanh Only','All Activation Functions'],\
                           title='Best Fitness Found with Uniform or Diverse Activations',getBest=True)
